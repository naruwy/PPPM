# %% [markdown]
# <a href="https://colab.research.google.com/github/naruwy/PPPM/blob/main/trading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
if not os.path.isdir("/content/drive"):
    drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! unzip /content/drive/MyDrive/gmo_coin/2022_report.zip -d /content/drive/MyDrive/gmo_coin/
# Out:
# Archive:  /content/drive/MyDrive/gmo_coin/2022_report.zip
#   inflating: /content/drive/MyDrive/gmo_coin/2022_trading_report.csv

# %%
import pandas as pd
import numpy as np

report = pd.read_csv('/content/drive/MyDrive/gmo_coin/2022_trading_report.csv')

# %%
report#['入出金金額'].sum()
report.columns
# Out:
# Index(['日時', '精算区分', '日本円受渡金額', '注文ID', '約定ID', '建玉ID', '銘柄名', '注文タイプ', '取引区分',
#        '売買区分', '執行条件', '約定数量', '約定レート', '約定金額', '注文手数料', 'レバレッジ手数料', '入出金区分',
#        '入出金金額', '授受区分', '数量', '送付手数料', '送付先/送付元', 'トランザクションID'],
#       dtype='object')

# %%
report
# Out:
#                   日時           精算区分  日本円受渡金額          注文ID  約定ID  建玉ID  銘柄名  \
# 0   2022/01/25 01:53         日本円入出金   100000           NaN   NaN   NaN  JPY
# 1   2022/01/25 01:56        取引所現物取引   -90215  2.207613e+09   NaN   NaN  ETH
# 2   2022/01/25 01:58        取引所現物取引    -2568  2.207614e+09   NaN   NaN  ETH
# 3   2022/01/25 01:59        取引所現物取引    -5146  2.207614e+09   NaN   NaN  ETH
# 4   2022/01/25 06:12  取引所現物 取引手数料返金        2           NaN   NaN   NaN  ETH
# 5   2022/01/27 00:08        取引所現物取引     6059  2.214171e+09   NaN   NaN  ETH
# 6   2022/01/27 00:08        取引所現物取引   109082  2.214171e+09   NaN   NaN  ETH
# 7   2022/01/27 06:12  取引所現物 取引手数料返金        1           NaN   NaN   NaN  ETH
# 8   2022/02/14 20:40        取引所現物取引  -106120  2.269823e+09   NaN   NaN  ETH
# 9   2022/02/14 20:41        取引所現物取引    -6634  2.269823e+09   NaN   NaN  ETH
# 10  2022/02/15 06:11  取引所現物 取引手数料返金        1           NaN   NaN   NaN  ETH
# ...
